# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaheloisa101195/colab/blob/main/aula3prof_marcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 3
lado2 = 2

 # Cálculo da área

area = lado1*lado2

# Cálculo da área de um quadrado

areaquadrado = lado1 *lado1

# %%
print (area)
# Out:
# 4

# %%
print (areaquadrado)
# Out:
# 9

# %%
nome = "Nycollas"
Idade = 15
altura = 1.8

# %%
print (nome)
# Out:
# Nycollas

# %%
nome= "aristides"

# %%
nome = "luiz"

# %%
print(f"nome : {nome},  idade: {Idade}, Altura: {altura}")
# Out:
# nome : Nycollas,  idade: 15, Altura: 1.8
