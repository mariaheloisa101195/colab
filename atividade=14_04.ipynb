# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaheloisa101195/colab/blob/main/atividade%3D14_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Par ou ímpar

numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("Par")
else:
    print("Ímpar")
# Out:
# Digite um número: 14
# Par

# %%
 #Maior de dois números

  # Estrutura de Decisões

# Escrever um programa que recebe 02 números e identifica o número maior.

# Entrada

numero1 = int (input ("digite um número: "))
numero2 = int (input ("digite um número: "))
 # Processamento e Saída

if numero1 > numero2:
  print (f"O número {numero1} é maior que o número {numero2}.")

elif numero2 > numero1:
  print (f"O número {numero2} é maior que o número {numero1}.")

else:
  print (f"Os números {numero1} e {numero2} são iguais.")
# Out:
# digite um número: 15
# digite um número: 14
# O número 15 é maior que o número 14.

# %%
  # Leitura da média
media = float(input("Digite a média final: "))

# Classificação
if media >= 7:
    print("Aprovado")
elif media >= 5:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Digite a média final: 1
# Reprovado

# %%
# Escrever um programa que o usuário digita o nome e idade:

  #Identificar se o usuário é criança, adolescente ou adulto.

  #> 12 criança
  #> 18 adolescente
  #< adulto

   # Saída (você é...)

  # Entrada

nome = str  (input ("digite seu nome"))
idade = int (input ("digite sua idade"))

# Processamento / Saída


if idade <= 12:
  print (f"ola {nome}, voce é criança")

elif idade  <= 18:
  print (f" ola {nome}, voce é adolescente")

elif idade <= 59:
  print (f"ola {nome}, voce é adulto")

else:
  print (f"ola {nome}, voce é idoso")
# Out:
# digite seu nome maria
# digite sua idade 3
# ola  maria, voce é criança

# %%
#Senha correta

#digite a senha correta

if == 5589:
  print ("senha correta")

else:
  print ("senha incorreta")
# Out:
#   File "/tmp/ipykernel_538/1353831358.py", line 5
#     if == 5589:
#        ^
# SyntaxError: invalid syntax

# %%
#Positivo, negativo ou zero

# %%
#Calculadora simples
# Out:
#   File "/tmp/ipykernel_538/751846991.py", line 1
#     Calculadora simples
#                 ^
# SyntaxError: invalid syntax

# %%
#Dia da semana

#Digite um numero e descubra o dia da semana

if == 1:
 print ("domingo")

elif  == 2:
 print ("segunda-feira")

elif == 3:
 print ("terça-feira")

elif == 4:
 print ("quarta-feira")

elif == 5:
 print ("quinta- feira")

elif == 6:
 print ("sexta-feira")

elif == 7:
 print ("sabado")

opção = int (input ("digite uma opção de 1 a 7: "))
# Out:
#   File "/tmp/ipykernel_538/65348179.py", line 5
#     if == 1:
#        ^
# SyntaxError: invalid syntax

# %%
#Ano bissexto

ano = int(input('Digite o ano: '))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f'{ano} é bissexto.')
else:
    print(f'{ano} não é bissexto.')
# Out:
# Digite o ano: 2000
# 2000 é bissexto.

# %%
 #Desconto em compras

  # pedir ao usuario para digitar 1 número

  #Identificar se o usuario tem direito a desconto.

  # >= 100 10% desconto
  # >= 50 5% com desconto
  # > 50 sem desconto

 # Entrada

 valor = float(input("Digite o valor da compra: "))

if valor <= 50:
    desconto = 0
elif valor >= 100:
    desconto = valor * 0.10
else:
    desconto = valor * 0.5

valor_final = valor - desconto

print("Valor final:", valor_final)
# Out:
# Digite o valor da compra: 49
# Valor final: 49.0
