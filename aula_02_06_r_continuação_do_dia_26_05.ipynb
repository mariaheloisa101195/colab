# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaheloisa101195/colab/blob/main/aula_02_06_r_continua%C3%A7%C3%A3o_do_dia_26_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calculadora simples
 # O programa recebera dois números e irá realizar uma das 4 operações matemáticas

opcao = ""
numero_a = 0
numero_b = 0

print ("----------MENU----------")
print ("")
print ("Opção 1 - Somar")
print ("Opção 2 - Subtração")
print ("Opção 3 - Multiplicação")
print ("Opção 4 - Divisão")
print ("Opção 5 - sair")
print ("======================")
print ("")


saldo = 1000
opção = 0


while opcao != 0:
  try:

     opcao = int (input("escolha a opção desejada"))
     print("")


     if opcao == 1:
       print(f"o seu saldo atual:{saldo}")

     elif opcao == 2:
      deposito = float (input("digite o valor que deseja depositar:"))
      saldo = saldo + deposito
      print("")

     elif opcao == 3:
      deposito = float (input("digite o valor que deseja sacar:"))
      saldo = saldo - deposito
      print ("")

     elif opcao < 0 or opcao > 3:
      print ("escolha uma opcao de 1 a 3 ou 4 para sair")

  except:
     print ("escolha opcao de 1 a 3 ou 4 para sair!")
# Out:
# ----------MENU----------
#
# Opção 1 - Somar
# Opção 2 - Subtração
# Opção 3 - Multiplicação
# Opção 4 - Divisão
# Opção 5 - sair
# ...
#
# escolha a opção desejada5
#
# escolha uma opcao de 1 a 3 ou 4 para sair
# escolha a opção desejada4
#
# escolha uma opcao de 1 a 3 ou 4 para sair
# escolha opcao de 1 a 3 ou 4 para sair!
# escolha opcao de 1 a 3 ou 4 para sair!
# escolha opcao de 1 a 3 ou 4 para sair!
# escolha opcao de 1 a 3 ou 4 para sair!

# %%
# biblioteca
# funciona como um sorteio
import random

a = random.random()

print (a)

# %%
# funciona como um sorteio (random) e o (random.randit) um sorteio com os numeros apresentados na variavel.
import random

a = random.randint (0, 10)
print (a)
# Out:
# 8

# %%
 # Fazer um jogo de adivinhação

 # O usuario ira adivinhar um numero de 0 até 10.

 # Regras

 # O usuario tera 3 chances para adivinhar.
 # Informar se o palpite do usuario é maior ou menor que o número.
 # Imprimir mensagem se está quente, morno ou frio.

opcao = ""
opcao_a = 0
opcao_b = 0
opcao_c = 0
